# %%
#정수형
a = 123
b = -170
c = 0

type(a)
# Out:
# int

# %%
# 실수형
a = 1.2
b = 4.2E-10
c = 3.14

type(c)
a = print(a)
type(a)
# Out:
# 1.2
# NoneType

# %%
# 8진수형 16진수
a = 0o177
a
8 **2 + 8*7 +7
# Out:
# 127

# %%
a = 0X8ff
a
# Out:
# 2303

# %%
(16 ** 2 * 8) + (16 * 15) + (15)
# Out:
# 2303

# %%
# 사칙연산
a = 3
b = 4

print(a+b)
print(a-b)
print(a*b)
print(a/b)
# Out:
# 7
# -1
# 12
# 0.75

# %%
a = 3
b = 4
a ** b
# Out:
# 81

# %%
16 ** 1/2
# Out:
# 8.0

# %%
#나눗셈 나머지를 연산하는 연산자
7 % 3
# Out:
# 1

# %%
7/3
# Out:
# 2.3333333333333335

# %%
#나눗셈 몫을 반환하는 //연산자
7/3
# Out:
# 2.3333333333333335

# %%
7//3
# Out:
# 2

# %%
# 복합연산자
a = 1
a = a + 1

print(a)
# Out:
# 2

# %%
a = 1
a += 1 #a = a + 1

print(a)

a -= 1 # a = a + 1
a += 1 # a = a - 1
a *= 1
a /= 1
# Out:
# 2
