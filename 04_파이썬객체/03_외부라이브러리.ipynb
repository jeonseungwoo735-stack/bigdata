# %%
# Do not reinvent the wheel

# %%
from faker import faker

fake = faker()
fake.name()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 from faker import faker
#       3 fake = faker()
#       4 fake.name()
#
# ImportError: cannot import name 'faker' from 'faker' (c:\Users\PC\AppData\Local\Programs\Python\Python314\Lib\site-packages\faker\__init__.py)

# %%
fake.address()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 fake.address()
#
# NameError: name 'fake' is not defined

# %%
test_data = [fake.name() , fake.address() for _ in range(30)]
print(test_data)
# Out:
#   Cell In[6], line 1
#     test_data = [fake.name() , fake.address() for _ in range(30)]
#                  ^
# SyntaxError: did you forget parentheses around the comprehension target?
