# %%
import module1

print(module1.add(3 , 4))
print(module1.sub(5 , 2))
# Out:
# 7
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 4
#       1 import module1
#       3 print(module1.add(3 , 4))
# ----> 4 print(module1.sub(5 , 2))
#
# TypeError: sub() takes 0 positional arguments but 2 were given

# %%
from module1 import *
print(add(10 , 20))
print(sub(10 , 30))
# Out:
# 30
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 3
#       1 from module1 import *
#       2 print(add(10 , 20))
# ----> 3 print(sub(10 , 30))
#
# TypeError: sub() takes 0 positional arguments but 2 were given
